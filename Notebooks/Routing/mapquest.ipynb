# %%
from gasp.fmshp               import shp_to_df
from gasp.pnd.mng             import split_df_inN, merge_df, split_df
from gasp.pnd.mng.geomattr    import pointxy_to_cols
from gasp.pnd.mng.prj         import project_df
from gasp.pnd.prop.feat       import df_geom_type
from gasp.toshp               import df_to_shp
from gasp.fmapi.mapqst        import matrix_route
from gasp.pnd.netanlst.mapqst import rev_geocode_df

# %%
#from gasp.pnd.netanlst.mapqst import matrix_route
import datetime

time_a = datetime.datetime.now().replace(microsecond=0)

ORIGENS  = r'C:\gis\compara_api\ex2\escolas_publicas.shp'
DESTINOS = r'C:\gis\compara_api\ex1\psp.shp'
RESULT   = r'C:\gis\compara_api\matriz_cost_od.shp'
EPSG     = 3763

#matrix_route
#cost_od(ORIGENS, DESTINOS, 3763, 3763, RESULT, mode="driving-car")

#time_b = datetime.datetime.now().replace(microsecond=0)

#print time_b - time_a

# %%
origens  = shp_to_df( ORIGENS)
destinos = shp_to_df(DESTINOS)

origens  = project_df(origens, 4326)
destinos = project_df(destinos, 4326)
"""
origens = pointxy_to_cols(
    origens, geomCol="geometry",
    colX="longitude", colY="latitude"
); destinos = pointxy_to_cols(
    destinos, geomCol="geometry",
    colX="longitude", colY="latitude"
)
"""
# Out:
# '\norigens = pointxy_to_cols(\n    origens, geomCol="geometry",\n    colX="longitude", colY="latitude"\n); destinos = pointxy_to_cols(\n    destinos, geomCol="geometry",\n    colX="longitude", colY="latitude"\n)\n'

# %%
origensWLoc = rev_geocode_df(origens, 4326)
print origensWLoc
# Out:
#     OBJECTID           COD_SIG IDTIPO  \
# 0          1  4202701045001001    999
# 1          2  4201702030001001    999
# 2          3  3503703010001001    999
# 3          4  1103701026001001    999
# 4          5  3001301052001001    999
# 5          6  4001302007001001    999
# 6          7  4202501006001001    999
# 7          8  3503001002001001    999
# 8          9  1003201193001001    999
# 9         10  0806702008001001    999
# 10        11  3306801011001001    999
# 11        12  4302215004001001    999
# 12        13  1102206001001001    999
# 13        14  0702105019001001    999
# 14        15  1804904027001001    999
# 15        16  0202802016001001    999
# 16        17  0202901048001001    999
# 17        18  3201301162001001    999
# 18        19  2107902001001001    999
# 19        20  5100901026001001    999
# 20        21  3307901010001001    999
# 21        22  4200801122001001    999
# 22        23  3900313010001001    999
# 23        24  2201205011001001    999
# 24        25  0703101004001001    999
# 25        26  2502105029001001    999
# 26        27  0601901071001001    999
# 27        28     4302901028001      2
# 28        29     2106901004001      2
# 29        30     4103703053001      2
# 30        31     2303802029001      2
# 31        32     3307203001001      2
# 32        33     3200201066001      2
# 33        34  0806704002001001    999
# 34        35  1301602001001001    999
# 35        36  0806601020001001    999
# 36        37  1805802025001001    999
# 37        38  1805802001001001    999
# 38        39  3303502031001001    999
# 39        40  1807404002001001    999
# 40        41  2105402017001001    999
# 41        42  3309101004001001    999
# 42        43  3310801002001001    999
#
#                                              INF_NOME  \
# 0               Escola Básica Almirante Gago Coutinho
# 1                  Escola Secundária Rainha D. Leonor
# 2                        Escola Básica Manuel da Maia
# 3                 Escola Secundária Vergílio Ferreira
# 4                       Escola Secundária Pedro Nunes
# 5                           Escola Secundária Restelo
# 6              Escola Secundária Padre António Vieira
# 7         Escola Básica e Secundária Josefa de Óbidos
# 8                    Escola Básica Marquesa de Alorna
# 9                    Escola Básica Quinta de Marrocos
# 10                             Escola Básica Piscinas
# 11  Escola Básica e Secundária D. Filipa de Lencastre
# 12                 Escola Básica Bairro do Padre Cruz
# 13                  Escola Básica Luis António Verney
# 14                       Escola Básica Alto do Lumiar
# 15                  Escola Básica Francisco de Arruda
# 16                 Escola Secundária Rainha D. Amélia
# 17                Escola Secundária Marquês de Pombal
# 18                              Escola Básica Marvila
# 19             Escola Básica e Secundária Gil Vicente
# 20                        Escola Básica Vasco da Gama
# 21                   Escola Básica Eugénio dos Santos
# 22              Escola Básica Professor Delfim Santos
# 23           Escola Básica e Secundária Passos Manuel
# 24                               Escola Básica Olaias
# 25                       Escola Básica Nuno Gonçalves
# 26               Escola Secundária D. Luísa de Gusmão
# 27                       Escola Básica Luís de Camões
# 28                Escola Secundária D. Dinis - Lisboa
# 29                    Escola Básica Patrício Prazeres
# 30                       Escola Secundária D. Pedro V
# 31                  Escola Secundária António Damásio
# 32                        Escola Básica Paula Vicente
# 33              Escola Secundária José Gomes Ferreira
# 34              Escola Básica Pintor Almada Negreiros
# 35                    Escola Básica Pedro de Santarém
# 36             Escola Básica Professor Lindley Cintra
# 37                           Escola Secundária Lumiar
# 38                      Escola Básica Fernando Pessoa
# 39                            Escola Básica Telheiras
# 40                       Escola Básica Damião de Góis
# 41                              Escola Básica Olivais
# 42                   Escola Secundária Eça de Queirós
#
#                                    INF_MORADA          INF_TELEFO INF_FAX  \
# 0                     Rua Dom Pedro de Cristo    +351 218 484 249    None
# 1            Rua Maria Amália Vaz de Carvalho    +351 218 428 880    None
# 2                        Rua Freitas Gazul, 6    +351 213 928 870    None
# 3    Rua do Seminário, Quinta dos Inglesinhos    +351 217 122 020    None
# 4                      Avenida Álvares Cabral  +351 213 940 090/1    None
# 5                         Rua Antão Gonçalves    +351 213 016 528    None
# 6                      Rua Marquês do Soveral    +351 218 484 111    None
# 7               Rua Coronel Ribeiro Viana, 11    +351 213 929 000    None
# 8                        Rua Dr. Júlio Dantas    +351 213 870 992    None
# 9                     Estrada de Benfica, 549    +351 217 112 330    None
# 10           Rua Capitão Santiago de Carvalho    +351 218 517 080    None
# 11                     Avenida Magalhães Lima    +351 218 407 045    None
# 12                Rua Professor Arsénio Nunes    +351 217 121 760    None
# 13                       Rua Marquês de Olhão    +351 218 610 100    None
# 14                     Avenida Carlos Paredes    +351 217 571 510    None
# 15                     Calçada da Tapada, 152    +351 213 616 480    None
# 16               Rua Jau, Alto de Santo Amaro    +351 213 616 060    None
# 17                  Rua Alexandre de Sá Pinto    +351 213 616 630    None
# 18   Rua António Gedeão - Bairro das Salgadas    +351 218 373 709    None
# 19                        Rua da Verónica, 37    +351 218 860 041    None
# 20                     Rua da Ilha dos Amores    +351 218 930 300    None
# 21                 Rua Luis Augusto Palmeirim    +351 218 429 940    None
# 22           Rua Maestro Frederico de Freitas    +351 217 783 167    None
# 23            Travessa do Convento de Jesus\n    +351 213 955 191    None
# 24               Rua Professor Mira Fernandes    +351 218 428 980    None
# 25                Avenida General Roçadas, 40    +351 218 147 488    None
# 26                Rua da Penha de França, 193    +351 218 161 160    None
# 27        Avenida Padre Manuel da Nóbrega, 15    +351 218 429 540    None
# 28                  Rua Manuel Teixeira Gomes    +351 218 310 190    None
# 29  Quinta das Comendadeiras, Alto do Varejão    +351 218 140 564    None
# 30               Estrada das Laranjeiras, 122    +351 217 246 060    None
# 31           Avenida Dr. Francisco Luís Gomes    +351 218 514 937    None
# 32                        Rua Gonçalves Zarco    +351 213 018 334    None
# 33           Rua Prof. José Sebastião e Silva    +351 217 121 470    None
# 34                Rua Vasco da Gama Fernandes    +351 217 567 190    None
# 35                    Estrada de Benfica, 535    +351 217 142 154    None
# 36                  Rua Mário Sampaio Ribeiro    +351 217 567 460    None
# 37                  Rua Mário Sampaio Ribeiro    +351 217 540 747    None
# 38                      Rua Cidade de Carmona    +351 218 503 150    None
# 39                      Rua Prof. Mário Chicó    +351 217 543 730    None
# 40                        Rua Cassiano Branco    +351 218 310 519    None
# 41                       Rua Cidade de Bolama    +351 218 540 520    None
# 42                     Rua Cidade de Benguela    +351 218 540 710    None
#
#                               INF_EMAIL  \
# 0                                  None
# 1       info_rdl@escolarainhadleonor.eu
# 2         geral@agescolasmanuelmaia.net
# 3                          esvf@aevf.pt
# 4           secretarialunos@espn.edu.pt
# 5                    geral@aerestelo.pt
# 6                 espav@mail.telepac.pt
# 7                ejo.ce@mail.telepac.pt
# 8   agrupamentomarquesaalorna@gmail.com
# 9                 aeqmarrocos@gmail.com
# 10      eb23-piscinassa@mail.telepac.pt
# 11      esfilipalencast@mail.telepac.pt
# 12                    eb23bpc@gmail.com
# 13             escoa.laverney@gmail.com
# 14                   aelumiar@gmail.com
# 15              farruda@mail.telepac.pt
# 16                esrda@mail.telepac.pt
# 17                                 None
# 18            info@eb23-marvila.rcts.pt
# 19                        geral@aegv.pt
# 20                coord.ebvg@queiroz.pt
# 21          dir.eugeniosantos@gmail.com
# 22                                 None
# 23                      espm@abc.edu.pt
# 24                eb23.olaias@gmail.com
# 25             aeng@aenunogoncalves.com
# 26  Esd.luisagusmao@aenunogoncalves.com
# 27               celuiscamoes@gmail.com
# 28                 gestao@esecddinis.pt
# 29               direcao.aepp@gmail.com
# 30                   direcao@ael.edu.pt
# 31                 direcao@aeolivais.pt
# 32                   geral@aerestelo.pt
{u'sideOfStreet': u'N', u'linkId': u'0', u'map...
# 42  {u'sideOfStreet': u'N', u'linkId': u'0', u'map...

# %%
destinosWLoc = rev_geocode_df(destinos, 4326)

# %%
# Get route distance for each origin
destLocations = destinosWLoc.locations.tolist()

def get_matrix(row):
    paramLoc = [row.locations] + destLocations
    
    row["results"] = matrix_route(paramLoc, option="oneToMany")
    
    return row

result = origensWLoc.apply(lambda x: get_matrix(x), axis=1)

# %%
destinosWLoc["old_fid"] = destinosWLoc.index
result["old_fid"] = result.index

# %%
mm = []
for row in range(result.shape[0]):
    for col in range(1 + destinosWLoc.shape[0]):
        if not col:
            ll = [result.iloc[row].old_fid, result.iloc[row].old_fid, result.iloc[row].results["distance"][col]]
        else:
            ll = [result.iloc[row].old_fid, destinosWLoc[col - 1].old_fid, result.iloc[row].results["distance"][col]]
        mm.append(ll)

matrix = pandas.DataFrame(mm, columns=["fid_origin", "fid_destin", "cost"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-29179ad9ab69> in <module>()
#       5             ll = [result.iloc[row].old_fid, result.iloc[row].old_fid, result.iloc[row].results["distance"][col]]
#       6         else:
# ----> 7             ll = [result.iloc[row].old_fid, destinosWLoc[col - 1].old_fid, result.iloc[row].results["distance"][col]]
#       8         mm.append(ll)
#       9
#
# c:\python27\arcgis10.5\lib\site-packages\geopandas\geodataframe.pyc in __getitem__(self, key)
#     445         GeoDataFrame.
#     446         """
# --> 447         result = super(GeoDataFrame, self).__getitem__(key)
#     448         geo_col = self._geometry_column_name
#     449         if isinstance(key, string_types) and key == geo_col:
#
# c:\python27\arcgis10.5\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# c:\python27\arcgis10.5\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# c:\python27\arcgis10.5\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# c:\python27\arcgis10.5\lib\site-packages\pandas\core\internals.pyc in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# c:\python27\arcgis10.5\lib\site-packages\pandas\indexes\base.pyc in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12322)()
#
# KeyError: 0

# %%
print result.iloc[0].results["distance"]
# Out:
# [0, 1.439, 1.725, 2.514, 2.78, 4.671, 2.327, 4.938, 3.49, 3.764, 2.922, 2.688, 4.478, 4.364, 4.12, 2.003, 6.003, 6.003, 3.542, 3.4, 5.359, 5.359, 5.331, 6.858, 6.739, 6.805, 2.476, 3.621, 2.966, 2.858, 1.501, 7.435, 7.28, 3.748, 2.664, 4.17, 3.458, 2.739, 2.739, 2.739, 2.867, 1.978, 2.498, 5.086, 3.954, 4.298, 4.42, 2.894, 4.064, 4.76, 3.17, 4.144, 4.491, 1.797, 2.901, 2.948, 4.181, 6.354, 2.862, 1.81, 1.725, 3.917]

# %%
# Split destinos em Dfs com 99 linhas

lst_destinos = split_df(destinos, 99)

# %%
row = origens.iloc[0]

# %%
# Para uma origem

postLocations = [{"latlng" : {
    "lat" : row["latitude"], "lng" : row["longitude"]
}}]
for df in lst_destinos:
    __destinos = df.latlng.tolist()
    
    #d = matrix_route(postLocations + __destinos, option="oneToMany")

# %%
locations = postLocations + __destinos
loc = locations[:2]
print loc

# %%
loc[0]['adminArea1'] = "PT"
loc[0]['adminArea1Type'] = "Country"
loc[1]['adminArea1'] = "PT"
loc[1]['adminArea1Type'] = "Country"
loc[0]['adminArea5'] = "Lisboa"
loc[0]['adminArea5Type'] = "City"
loc[1]['adminArea5'] = "Lisboa"
loc[1]['adminArea5Type'] = "City"
print loc

# %%
d = matrix_route(loc, option="oneToMany")

# %%
for k in d:
    print k
    print d[k]
    print "-----------"
